# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from processing.pipelines import pipeline_modes_parities

# %%
Ms = 1.42e5 #[A / m]
gamma = 2.21e5 #[m / (A * s)]

# %%
paths = (
    'data_rep/Cyl/parities/mXY',
    'data_rep/Cyl/parities/mXZ',
    'data_rep/Cyl/parities/mYZ',
)

df = pipeline_modes_parities(paths=paths)
# Out:
# While hendling complex numbers exception Can only use .str accessor with string values! of the type <class 'AttributeError'> occured
# While hendling complex numbers exception 'NoneType' object is not subscriptable of the type <class 'TypeError'> occured
# While hendling complex numbers exception Can only use .str accessor with string values! of the type <class 'AttributeError'> occured
# While hendling complex numbers exception Can only use .str accessor with string values! of the type <class 'AttributeError'> occured
# /home/aluatar/.local/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:133: ComplexWarning: Casting complex values to real discards the imaginary part
#   return arr.astype(dtype, copy=True)
# While hendling complex numbers exception Can only use .str accessor with string values! of the type <class 'AttributeError'> occured
# While hendling complex numbers exception 'NoneType' object is not subscriptable of the type <class 'TypeError'> occured
# ...

# %%
fig = plt.figure(figsize=(4,8), dpi=300)

ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

_df = df#.loc[df['pXZ']==-1]
ax1.scatter(_df['param_0'], _df['ef_1'], s=2, c=df['pXZ'])
ax2.scatter(_df['param_0'], _df['ef_1'], s=2, c=df['pYZ'])
ax3.scatter(_df['param_0'], _df['ef_1'], s=2, c=df['pXY'])

ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')

# %%
fig = plt.figure(figsize=(4,4), dpi=300)

ax = fig.add_subplot(111)

_df = df#.loc[df['pXZ']==-1]
ax.scatter(_df['param_0'], _df['ef_1'], s=2, c=df['pXZ'])
ax.set_yscale('log')
